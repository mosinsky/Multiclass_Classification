# %%
# %run ./imports.ipynb

# %% [markdown]
# # dataset - https://www.kaggle.com/datasets/abhishek14398/automatic-ticket-classification-dataset/data

# %%
path = "complaints.json"
open_path = open(path) 
read_data = json.load(open_path)
df=pd.json_normalize(read_data)

# %%
df = df[['_source.complaint_what_happened','_source.product','_source.sub_product']]
df = df.rename(columns={'_source.complaint_what_happened': 'complaint_text', '_source.product': 'category','_source.sub_product': 'sub_category'})

# %%
# lets merge the category and sub-category this will help us in deciding the topics after NMF modelling
df['category'] = df['category'] + '+' + df['sub_category']
df = df.drop(['sub_category'],axis= 1)

# %%
df[df['complaint_text']==''] = np.nan
df.complaint_text.isnull().sum()
# Out:
# 57241

# %%
df = df[~df['complaint_text'].isnull()]
df.complaint_text.isnull().sum()
# Out:
# 0

# %%
df.category.value_counts()
# Out:
# Credit card or prepaid card+General-purpose credit card or charge card                                         4918
# Checking or savings account+Checking account                                                                   3788
# Credit reporting, credit repair services, or other personal consumer reports+Credit reporting                  2011
# Bank account or service+Checking account                                                                       1242
# Mortgage+Conventional home mortgage                                                                             955
# Mortgage+Conventional fixed mortgage                                                                            785
# Mortgage+FHA mortgage                                                                                           496
# Debt collection+Credit card debt                                                                                427
# Money transfer, virtual currency, or money service+Domestic (US) money transfer                                 344
# Bank account or service+Other bank product/service                                                              301
# Vehicle loan or lease+Loan                                                                                      284
# Mortgage+Conventional adjustable mortgage (ARM)                                                                 280
# Checking or savings account+Other banking product or service                                                    242
# Checking or savings account+Savings account                                                                     232
# Debt collection+Credit card                                                                                     222
# Money transfer, virtual currency, or money service+Mobile or digital wallet                                     195
# Mortgage+Other mortgage                                                                                         192
# Consumer Loan+Vehicle loan                                                                                      174
# Mortgage+Home equity loan or line of credit (HELOC)                                                             163
# Mortgage+Home equity loan or line of credit                                                                     161
# Vehicle loan or lease+Lease                                                                                     119
# Mortgage+Other type of mortgage                                                                                 112
# Money transfer, virtual currency, or money service+International money transfer                                 108
# Student loan+Non-federal student loan                                                                           104
# Mortgage+VA mortgage                                                                                             97
# Debt collection+I do not know                                                                                    85
# Bank account or service+Savings account                                                                          69
# Debt collection+Mortgage debt                                                                                    64
# Credit reporting, credit repair services, or other personal consumer reports+Other personal consumer report      62
# Credit card or prepaid card+Store credit card                                                                    53
# Debt collection+Mortgage                                                                                         50
# Money transfer, virtual currency, or money service+Virtual currency                                              48
# Credit card or prepaid card+General-purpose prepaid card                                                         42
# Money transfers+Domestic (US) money transfer                                                                     34
# Money transfer, virtual currency, or money service+Traveler's check or cashier's check                           33
# Consumer Loan+Installment loan                                                                                   33
# Debt collection+Auto debt                                                                                        32
# Debt collection+Other debt                                                                                       31
# Checking or savings account+CD (Certificate of Deposit)                                                          27
# Consumer Loan+Vehicle lease                                                                                      26
# Student loan+Private student loan                                                                                25
# Money transfers+International money transfer                                                                     22
# Money transfer, virtual currency, or money service+Money order                                                   19
# Bank account or service+(CD) Certificate of deposit                                                              19
# Debt collection+Other (i.e. phone, health club, etc.)                                                            19
# Bank account or service+Cashing a check without an account                                                       19
# Money transfer, virtual currency, or money service+Check cashing service                                         19
# Payday loan, title loan, or personal loan+Personal line of credit                                                18
# Money transfer, virtual currency, or money service+Foreign currency exchange                                     15
# Payday loan, title loan, or personal loan+Installment loan                                                       14
# Credit reporting, credit repair services, or other personal consumer reports+Credit repair services              14
# Student loan+Federal student loan servicing                                                                      11
# Money transfer, virtual currency, or money service+Refund anticipation check                                     11
# Credit card or prepaid card+Government benefit card                                                              11
# Debt collection+Auto                                                                                              9
# Credit card or prepaid card+Gift card                                                                             9
# Payday loan, title loan, or personal loan+Title loan                                                              9
# Debt collection+Private student loan debt                                                                         7
# Credit card or prepaid card+Payroll card                                                                          6
# Mortgage+Reverse mortgage                                                                                         5
# Debt collection+Non-federal student loan                                                                          5
# Money transfer, virtual currency, or money service+Debt settlement                                                5
# Consumer Loan+Pawn loan                                                                                           4
# Other financial service+Check cashing                                                                             4
# Consumer Loan+Title loan                                                                                          3
# Payday loan, title loan, or personal loan+Payday loan                                                             3
# Prepaid card+General purpose card                                                                                 2
# Debt collection+Payday loan debt                                                                                  2
# Other financial service+Traveler’s/Cashier’s checks                                                               2
# Other financial service+Foreign currency exchange                                                                 2
# Prepaid card+Government benefit payment card                                                                      2
# Other financial service+Money order                                                                               1
# Debt collection+Federal student loan                                                                              1
# Prepaid card+Other special purpose card                                                                           1
# Checking or savings account+Personal line of credit                                                               1
# Prepaid card+Electronic Benefit Transfer / EBT card                                                               1
# Debt collection+Payday loan                                                                                       1
# Prepaid card+Gift or merchant card                                                                                1
# Name: category, dtype: int64

# %% [markdown]
# # text cleaning

# %%
# %run ./preprocessing.ipynb
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (23.3.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: spacy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (0.3.2)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (2.4.2)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from spacy) (1.24.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.6)
# Requirement already satisfied: cloudpathlib<0.16.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->spacy) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
stopwords = nlp.Defaults.stop_words
def clean(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text) #special characters
    text = re.sub('\[.*\]','', text).strip() #brackets
    text = re.sub('\S*\d\S*\s*','', text).strip() #numbers
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]
    text = ' '.join(tokens)
    # return text.strip()
    return text.strip()

def lemmatizer(text):
    doc = nlp(text)
    sent = [token.lemma_ for token in doc if not token.text in set(stopwords)]
    return ' '.join(sent)

def spacy_tags_remove(text):
    doc = nlp(text)
    sent = [token.text for token in doc if token.tag_ == 'NN']
    return ' '.join(sent)

# %%
df['clean_text'] = df.complaint_text.apply(lambda x: clean(x))
df.head()
# Out:
#                                        complaint_text  \
# 1   Good morning my name is XXXX XXXX and I apprec...
# 2   I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 10  Chase Card was reported on XX/XX/2019. However...
# 11  On XX/XX/2018, while trying to book a XXXX  XX...
# 14  my grand son give me check for {$1600.00} i de...
#
#                                              category  \
# 1                    Debt collection+Credit card debt
# 2   Credit card or prepaid card+General-purpose cr...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14       Checking or savings account+Checking account
#
#                                            clean_text
# 1   good morn name xxxx xxxx appreci could help pu...
# 2   upgrad xxxx xxxx card xxxx told agent upgrad a...
# 10  chase card report xxxx howev fraudul applic su...
# 11  xxxx tri book xxxx xxxx ticket came across off...
# 14  grand son give check deposit chase account fun...

# %%
df['lem'] =  df.clean_text.apply(lambda x: lemmatizer(x))
df.head()
# Out:
#                                        complaint_text  \
# 1   Good morning my name is XXXX XXXX and I apprec...
# 2   I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 10  Chase Card was reported on XX/XX/2019. However...
# 11  On XX/XX/2018, while trying to book a XXXX  XX...
# 14  my grand son give me check for {$1600.00} i de...
#
#                                              category  \
# 1                    Debt collection+Credit card debt
# 2   Credit card or prepaid card+General-purpose cr...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14       Checking or savings account+Checking account
#
#                                            clean_text  \
# 1   good morn name xxxx xxxx appreci could help pu...
# 2   upgrad xxxx xxxx card xxxx told agent upgrad a...
# 10  chase card report xxxx howev fraudul applic su...
# 11  xxxx tri book xxxx xxxx ticket came across off...
# 14  grand son give check deposit chase account fun...
#
#                                                   lem
# 1   good morn xxxx xxxx appreci help stop chase ba...
# 2   upgrad xxxx xxxx card xxxx tell agent upgrad a...
# 10  chase card report xxxx howev fraudul applic su...
# 11  xxxx tri book xxxx xxxx ticket come offer appl...
# 14  grand son check deposit chase account fund cle...

# %%
df_new = df[['complaint_text','lem','category']]
df_new.head()
# Out:
#                                        complaint_text  \
# 1   Good morning my name is XXXX XXXX and I apprec...
# 2   I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 10  Chase Card was reported on XX/XX/2019. However...
# 11  On XX/XX/2018, while trying to book a XXXX  XX...
# 14  my grand son give me check for {$1600.00} i de...
#
#                                                   lem  \
# 1   good morn xxxx xxxx appreci help stop chase ba...
# 2   upgrad xxxx xxxx card xxxx tell agent upgrad a...
# 10  chase card report xxxx howev fraudul applic su...
# 11  xxxx tri book xxxx xxxx ticket come offer appl...
# 14  grand son check deposit chase account fund cle...
#
#                                              category
# 1                    Debt collection+Credit card debt
# 2   Credit card or prepaid card+General-purpose cr...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14       Checking or savings account+Checking account

# %%
df_new['after_POS'] =  df_new.lem.apply(lambda x: spacy_tags_remove(x))
df_new.head()
# Out:
#                                        complaint_text  \
# 1   Good morning my name is XXXX XXXX and I apprec...
# 2   I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 10  Chase Card was reported on XX/XX/2019. However...
# 11  On XX/XX/2018, while trying to book a XXXX  XX...
# 14  my grand son give me check for {$1600.00} i de...
#
#                                                   lem  \
# 1   good morn xxxx xxxx appreci help stop chase ba...
# 2   upgrad xxxx xxxx card xxxx tell agent upgrad a...
# 10  chase card report xxxx howev fraudul applic su...
# 11  xxxx tri book xxxx xxxx ticket come offer appl...
# 14  grand son check deposit chase account fund cle...
#
#                                              category  \
# 1                    Debt collection+Credit card debt
# 2   Credit card or prepaid card+General-purpose cr...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14       Checking or savings account+Checking account
#
#                                             after_POS
# 1   write chase debt verif statement bank debt mai...
# 2            agent date agent inform order agent misl
# 10     chase card report consent extend credit verifi
# 11  ticket appli ticket appli reward card inform i...
# 14  son deposit chase account fund bank account pa...
